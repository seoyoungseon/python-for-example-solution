# %% [markdown]
# 1. 다음 `if` 문장을 대신할 수 있는 코드를 사전을 이용해서 작성해보시오.
# ```python
# if choice == 'ramyon`:
#     price = 3000
# elif choice == 'gimbab':
#     price = 2500
# elif choice = 'soondae':
#     price = 5000
# else:
#     price = 0
# ```

# %%
menus = {'ramyon':3000, 'gimbab':2500, 'soondae':5000}
menu = input("메뉴를 고르시오: ")


print(menus.get(menu,0))
# Out:
# 메뉴를 고르시오: soondae
# 5000
