# %% [markdown]
# 1.명령 프롬프트를 실행하시오.

# %% [markdown]
# 2.usb 메모리를 컴퓨터에 연결하고 exercises 디렉토리를 만드시오.

# %%
J:
mkdir exercises

# %% [markdown]
# 3.usb 메모리에 만든 exercises 디렉토리로 이동하시오.

# %%
cd exercises

# %% [markdown]
# 4.쥬피터 노트북을 실행하고 종료해보시오.

# %%
jupyter notebook #실행
# 쥬피터노트북을 실행한 명령프롬프트에서 ctrl+C를 누르면 종료
